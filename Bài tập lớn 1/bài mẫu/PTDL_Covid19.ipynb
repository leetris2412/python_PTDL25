# %% [markdown]
# # Nhiệm vụ 1: Khám phá dữ liệu COVID

# %% [markdown]
# import thư viện

# %%
import numpy as np
import pandas as pd
from scipy import stats

# %%
# Load the .csv into a dataframe using read_csv
covid_data = pd.read_csv("owid-covid-data.csv")
covid_data = covid_data[['iso_code','continent','location','date','total_cases','new_cases']]

# %%
# Take a quick look at the data
covid_data.head(50)
# Out:
#    iso_code continent     location        date  total_cases  new_cases
# 0       AFG      Asia  Afghanistan  2020-01-05          0.0        0.0
# 1       AFG      Asia  Afghanistan  2020-01-06          0.0        0.0
# 2       AFG      Asia  Afghanistan  2020-01-07          0.0        0.0
# 3       AFG      Asia  Afghanistan  2020-01-08          0.0        0.0
# 4       AFG      Asia  Afghanistan  2020-01-09          0.0        0.0
# 5       AFG      Asia  Afghanistan  2020-01-10          0.0        0.0
# 6       AFG      Asia  Afghanistan  2020-01-11          0.0        0.0
# 7       AFG      Asia  Afghanistan  2020-01-12          0.0        0.0
# 8       AFG      Asia  Afghanistan  2020-01-13          0.0        0.0
# 9       AFG      Asia  Afghanistan  2020-01-14          0.0        0.0
# 10      AFG      Asia  Afghanistan  2020-01-15          0.0        0.0
# 11      AFG      Asia  Afghanistan  2020-01-16          0.0        0.0
# 12      AFG      Asia  Afghanistan  2020-01-17          0.0        0.0
# 13      AFG      Asia  Afghanistan  2020-01-18          0.0        0.0
# 14      AFG      Asia  Afghanistan  2020-01-19          0.0        0.0
# 15      AFG      Asia  Afghanistan  2020-01-20          0.0        0.0
# 16      AFG      Asia  Afghanistan  2020-01-21          0.0        0.0
# 17      AFG      Asia  Afghanistan  2020-01-22          0.0        0.0
# 18      AFG      Asia  Afghanistan  2020-01-23          0.0        0.0
# 19      AFG      Asia  Afghanistan  2020-01-24          0.0        0.0
# 20      AFG      Asia  Afghanistan  2020-01-25          0.0        0.0
# 21      AFG      Asia  Afghanistan  2020-01-26          0.0        0.0
# 22      AFG      Asia  Afghanistan  2020-01-27          0.0        0.0
# 23      AFG      Asia  Afghanistan  2020-01-28          0.0        0.0
# 24      AFG      Asia  Afghanistan  2020-01-29          0.0        0.0
# 25      AFG      Asia  Afghanistan  2020-01-30          0.0        0.0
# 26      AFG      Asia  Afghanistan  2020-01-31          0.0        0.0
# 27      AFG      Asia  Afghanistan  2020-02-01          0.0        0.0
# 28      AFG      Asia  Afghanistan  2020-02-02          0.0        0.0
# 29      AFG      Asia  Afghanistan  2020-02-03          0.0        0.0
# 30      AFG      Asia  Afghanistan  2020-02-04          0.0        0.0
# 31      AFG      Asia  Afghanistan  2020-02-05          0.0        0.0
# 32      AFG      Asia  Afghanistan  2020-02-06          0.0        0.0
# 33      AFG      Asia  Afghanistan  2020-02-07          0.0        0.0
# 34      AFG      Asia  Afghanistan  2020-02-08          0.0        0.0
# 35      AFG      Asia  Afghanistan  2020-02-09          0.0        0.0
# 36      AFG      Asia  Afghanistan  2020-02-10          0.0        0.0
# 37      AFG      Asia  Afghanistan  2020-02-11          0.0        0.0
# 38      AFG      Asia  Afghanistan  2020-02-12          0.0        0.0
# 39      AFG      Asia  Afghanistan  2020-02-13          0.0        0.0
# 40      AFG      Asia  Afghanistan  2020-02-14          0.0        0.0
# 41      AFG      Asia  Afghanistan  2020-02-15          0.0        0.0
# 42      AFG      Asia  Afghanistan  2020-02-16          0.0        0.0
# 43      AFG      Asia  Afghanistan  2020-02-17          0.0        0.0
# 44      AFG      Asia  Afghanistan  2020-02-18          0.0        0.0
# 45      AFG      Asia  Afghanistan  2020-02-19          0.0        0.0
# 46      AFG      Asia  Afghanistan  2020-02-20          0.0        0.0
# 47      AFG      Asia  Afghanistan  2020-02-21          0.0        0.0
# 48      AFG      Asia  Afghanistan  2020-02-22          0.0        0.0
# 49      AFG      Asia  Afghanistan  2020-02-23          0.0        0.0

# %%
covid_data.dtypes
# Out:
# iso_code        object
# continent       object
# location        object
# date            object
# total_cases    float64
# new_cases      float64
# dtype: object

# %%
covid_data.shape
# Out:
# (429435, 6)

# %%
# Get the mean of the data
data_mean = np.mean(covid_data["new_cases"])
print("Mean of new cases:", data_mean)
# Out:
# Mean of new cases: 8017.359933586731

# %%
# Get the median of the data
data_median = np.median(covid_data["new_cases"])
print("Median of new cases:", data_median)
# Out:
# Median of new cases: nan

# %%
# Get the mode of the data
data_mode = stats.mode(covid_data["new_cases"])
print("Mode of new cases:", data_mode)
# Out:
# Mode of new cases: ModeResult(mode=0.0, count=368385)

# %%
# Obtain the variance of the data
data_variance = np.var(covid_data["new_cases"])
print("Variance of new cases:", data_variance)
# Out:
# Variance of new cases: 52745822411.38847

# %%
# Obtain the standard deviation of the data
data_sd = np.std(covid_data["new_cases"])
print("Standard Deviation of new cases:", data_sd)
# Out:
# Standard Deviation of new cases: 229664.58675944898

# %%
# Compute the maximum and minimum values of the data
data_max = np.max(covid_data["new_cases"])
data_min = np.min(covid_data["new_cases"])
print("Maximum of new cases:", data_max)
print("Minimum of new cases:", data_min)
# Out:
# Maximum of new cases: 44236227.0
# Minimum of new cases: 0.0

# %%
# Obtain the 60th percentile of the data
data_percentile = np.percentile(covid_data["new_cases"],60)
print("60th Percentile of new cases:", data_percentile)
# Out:
# 60th Percentile of new cases: nan

# %%
# Obtain the quartiles of the data
data_quartile = np.quantile(covid_data["new_cases"],0.75)
print("75th Quartile of new cases:", data_quartile)
# Out:
# 75th Quartile of new cases: nan

# %%
# Get the IQR of the data
data_IQR = stats.iqr(covid_data["new_cases"])
print("Interquartile Range (IQR) of new cases:", data_IQR)
# Out:
# Interquartile Range (IQR) of new cases: nan

# %% [markdown]
# Kết thúc
