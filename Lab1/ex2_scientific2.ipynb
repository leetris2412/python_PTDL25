# %%
#%% md

# %% [markdown]
# # ex2_scientific1

# %%
## Nội dung bài

# %% [markdown]
# Hiển thị ngẫu nhiên $N=50$ hình tròn:
# + Tâm $c_i = (x_i,y_i)$ ngẫu nhiên với $x_i, y_i \in \left[0, 1 \right]$
# + Màu sắc $color_i$ ngẫu nhiên với $color_i \in \left[0, 1 \right]$
# + Diện tích $area_i = \pi * r_i^2$ với sinh ngẫu nhiên $r_i \in \left[0, 1 \right]$

# %% [markdown]
# ## Bài làm

# %% [markdown]
# #%% md

# %% [markdown]
# ### Import thư viện

# %% [markdown]
# #%%

# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython import display # hiển thị rich output

# %% [markdown]
# #%% md

# %% [markdown]
# ### Sinh ngẫu nhiên hình tròn

# %% [markdown]
# #%%

# %% [markdown]
# %time

# %% [markdown]
# # generate randomly the center (x,y ) of circle, color, area

# %%
N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = np.pi * (15 * np.random.rand(N)) ** 2  # 0 to 15 point radii

# %% [markdown]
# #%%

# %% [markdown]
# # Mã kiểm tra dữ liệu

# %%
print(f'+ x: len={len(x):d}, [{min(x):.2f}, {max(x):.2f}]: 10 samples [{x[0:10]}]')
print(f'+ y: len={len(y):d}, [{min(y):.2f}, {max(y):.2f}]: 10 samples [{y[0:10]}]')
print(f'+ colors: len={len(colors):d}, [{min(colors):.2f}, {max(colors):.2f}]: 10 samples [{colors[0:10]}]')
print(f'+ area: len={len(area):d}, [{min(area):.2f}, {max(area):.2f}]: 10 samples [{area[0:10]}]')
# Out:
# + x: len=50, [0.01, 0.99]: 10 samples [[0.28219132 0.80283441 0.25340454 0.20254606 0.43207661 0.43210852
#  0.06295892 0.42795024 0.28509247 0.55780155]]
# + y: len=50, [0.01, 1.00]: 10 samples [[0.53549446 0.11430313 0.664771   0.837152   0.97342987 0.10469576
#  0.99506129 0.3170407  0.56667248 0.49277781]]
# + colors: len=50, [0.00, 0.98]: 10 samples [[0.41782996 0.56860954 0.83413734 0.09501419 0.74174392 0.03061982
#  0.8772857  0.20435328 0.28504985 0.5662754 ]]
# + area: len=50, [0.07, 694.99]: 10 samples [[ 93.69687786 231.66375299  80.02177831 618.72270798  41.83006799
#  127.33815453 272.10439258 235.6553079  558.68188898 524.26632322]]

# %% [markdown]
# #%% md

# %% [markdown]
# ### Hiển thị đồ thị

# %% [markdown]
# #%%

# %% [markdown]
# %matplotlib inline

# %%
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.show()

# %% [markdown]
# #%% md

# %% [markdown]
# # Kết thúc
